# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# # Here in our case our model is poor bcz we have taken almost linear data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('C:\\Academics\\Machine-Learning\\algorithms\\height_weight_data.csv')

# %%
df.head()
# Out:
#    Height (cm)  Weight (kg)
# 0          150           50
# 1          160           60
# 2          170           70
# 3          180           80
# 4          155           55

# %%
x=df[['Height (cm)']]
y=df[['Weight (kg)']]
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %% [markdown]
# #Applied Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_train
# Out:
# array([[-1.61238774],
#        [ 1.35780021],
#        [ 0.08486251],
#        [-0.08486251],
#        [-1.18807518],
#        [ 0.93348764],
#        [ 0.50917508]])

# %%
X_test=scaler.transform(X_test)
# Out:
# c:\Academics\Machine-Learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()

# %%
regressor.fit(X_train,y_train)
regressor.coef_
# Out:
# array([[11.78376607]])

# %%
regressor.intercept_
# Out:
# array([69.])

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')

# %% [markdown]
# #prediction for the test data

# %%
y_pred = regressor.predict(X_test)

# %%
#performance metrics
from sklearn.metrics import mean_squared_error , mean_absolute_error
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
rmse = np.sqrt(mse)

# %%
print('Mean Squared Error :',mse)
print('Mean Absolute Error :',mae)
print('Root Mean Squared Error :',rmse)
# Out:
# Mean Squared Error : 31183.407556488633
# Mean Absolute Error : 176.56373206252712
# Root Mean Squared Error : 176.58824297355878

# %%
#Applying R^2
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
print('R^2 :',r2)
# Out:
# R^2 : -3597.08548728715
