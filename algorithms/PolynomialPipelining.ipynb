# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # this is how pipelining is done of polynomial regression

# %%
def poly_regression(degree):
    # new data being made here xnew
    poly_features = PolynomialFeatures(degree,include_bias=True)
    regression = LinearRegression()
    poly_regression=Pipeline([
        ('poly-features',poly_regression),
        ('linear-regression',regression)
    ])
    poly_regression.fit(xtrain,ytrain)
    y-pred-new = regression.predict(xnew)


    #plotting the line chart
    plt.plot(y-pred-new , xnew)
    plt.plot(xtrain,ytrain)
