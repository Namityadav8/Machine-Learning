# %%
import pandas as pd

# %%
data ={
    'name': ['John', 'Anna', 'Peter', 'Linda'],
    'location': ['New York', 'Paris', 'Berlin', 'London']
}
df=pd.DataFrame(data)
print(df.loc[1:3,'location'])
# Out:
# 1     Paris
# 2    Berlin
# 3    London
# Name: location, dtype: object

# %%
data1 ={
    'name': ['John', 'Anna', 'Peter', 'Linda'],
    'location': ['New York', 'Paris', 'Berlin', 'London']
}

df1=pd.DataFrame(data1)
print(df1.iloc[1,:])
# Out:
# name         Anna
# location    Paris
# Name: 1, dtype: object
