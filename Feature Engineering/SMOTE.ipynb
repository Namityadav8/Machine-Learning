# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=1000,n_redundant=0,n_features=2,n_clusters_per_class=1,weights=[0.09],random_state=12)

# %%
import pandas as pd

# %%
df1=pd.DataFrame(x,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
final_df=pd.concat([df1,df2],axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -1.267359  0.779033       1
# 1 -0.914085  1.120104       1
# 2 -1.447578  0.173241       1
# 3 -2.023284 -0.428945       1
# 4 -1.222044  0.178239       1

# %%
final_df['target'].value_counts()
# Out:
# target
# 1    907
# 0     93
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
#Now we have to apply the smot for this

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\academics\machine-learning\.venv\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\academics\machine-learning\.venv\lib\site-packages (from imblearn) (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\academics\machine-learning\.venv\lib\site-packages (from imbalanced-learn->imblearn) (2.2.1)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\academics\machine-learning\.venv\lib\site-packages (from imbalanced-learn->imblearn) (1.15.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\academics\machine-learning\.venv\lib\site-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\academics\machine-learning\.venv\lib\site-packages (from imbalanced-learn->imblearn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\academics\machine-learning\.venv\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\academics\machine-learning\.venv\lib\site-packages (from imbalanced-learn->imblearn) (3.5.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample=SMOTE()
x,y= oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
x.shape
# Out:
# (1814, 2)

# %%
y.shape
y==0
y[y==0]
# Out:
# 20      0
# 25      0
# 35      0
# 37      0
# 52      0
#        ..
# 1809    0
# 1810    0
# 1811    0
# 1812    0
# 1813    0
# Name: target, Length: 907, dtype: int64

# %%
len(y[y==0])
# Out:
# 907

# %%
df1=pd.DataFrame(x,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
oversample_df=pd.concat([df1,df2],axis=1)

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['target'])
