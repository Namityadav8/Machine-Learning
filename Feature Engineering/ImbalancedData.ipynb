# %%
import numpy as np
import pandas as pd

# %%
n_samples=1000
class_0_ratio=0.9
n_class_ratio=int(n_samples*class_0_ratio)
n_class_1=n_samples-n_class_ratio

n_class_ratio,n_class_1
# Out:
# (900, 100)
