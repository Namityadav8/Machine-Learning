# %% [markdown]
# #Bar plot is used for only categorical values

# %%
import matplotlib.pyplot as plt

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [7, 13, 5, 17, 10]
plt.title('Bar chart')
plt.bar(categories, values,color='blue',edgecolor='red')
# Out:
# <BarContainer object of 5 artists>
