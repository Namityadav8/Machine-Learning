# %% [markdown]
# Histogram is used to represant the distribution of the data. it divides the data into bins and counts the no. of data points in each node.

# %%
import matplotlib.pyplot as plt

# %%
data=[1,23,42,25,57,3,64,34,635,235]
plt.hist(data,bins=5,color='red',edgecolor='black')
# Out:
# (array([8., 1., 0., 0., 1.]),
#  array([  1. , 127.8, 254.6, 381.4, 508.2, 635. ]),
#  <BarContainer object of 5 artists>)
