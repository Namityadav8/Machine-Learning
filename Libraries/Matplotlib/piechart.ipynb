# %%
import matplotlib.pyplot as plt

# %%
data = [30,20,40,10]
labelled = ['A','B','C','D']
colored = ['red','blue','green','yellow']
exploded = [0,0,0.3,0]

plt.pie(data,labels=labelled,colors=colored,explode=exploded,autopct='%1.f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2ae067ea210>,
# ...
#  [Text(0.6465637011386807, 0.8899187493079641, 'A'),
#   Text(-0.8899187390319623, 0.6465637152823859, 'B'),
#   Text(-0.43262394661203507, -1.3314790726173007, 'C'),
#   Text(1.0461621838648125, -0.339918644753721, 'D')],
#  [Text(0.3526711097120076, 0.48541022689525304, '30%'),
#   Text(-0.4854102212901612, 0.3526711174267559, '20%'),
#   Text(-0.27811539425059395, -0.8559508323968361, '40%'),
#   Text(0.5706339184717159, -0.185410169865666, '10%')])
